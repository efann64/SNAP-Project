# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import autoreload
# %load_ext autoreload
# %autoreload 2

# %%
#New Mexico, using github files to see if there is a change in my corr csv
nm07 = pd.read_csv(r'C:\Users\efann\NEWclean_nm07.csv')
nm17 = pd.read_csv(r'C:\Users\efann\NEWclean_nm17.csv')


#Nebraska, using github files to see if there is a change in my corr csv
ne07 = pd.read_csv(r'C:\Users\efann\NEWclean_ne07.csv')
ne17 = pd.read_csv(r'C:\Users\efann\NEWclean_ne17.csv')

# %%
#These codes are from the SCRIPTS folder on decca10's Github page
def corr_df(fullname, dataset):
    """Creates a dataframe on .corr(), used for UNIT categories."""
    fullname_df = pd.DataFrame()
    for feature in fullname['Table 1']:
        try:
            fullname_df[feature] = dataset[feature]
        except:
            continue
    fullname_df['CAT_ELIG']=dataset['CAT_ELIG'].astype("float64")
    return fullname_df

def corr_numcol(fullname,dataset):
    """Creates a dataframe on .corr(), used for PERSONAL CHARACTERISTICS categories."""
    fullname_df=pd.DataFrame()
    for feature in fullname['Table 1']:
        feature = feature[:-1]
        for num in range(1,17):
            combo=str(feature+str(num))
            try:
                fullname_df[combo]=dataset[combo]
            except:
                continue
    fullname_df['CAT_ELIG']=dataset['CAT_ELIG'].astype('float64')
    return fullname_df

# %%
######################
#2007 DATA from github
######################

unit07_demo= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2007NEWDataDictionary\UNIT_Demo.csv')
unit07_assets= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2007NEWDataDictionary\UNIT_Assets.csv')
unit07_exded= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2007NEWDataDictionary\UNIT_ExDed.csv')
unit07_inc= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2007NEWDataDictionary\UNIT_Inc.csv')
pers07_char= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2007NEWDataDictionary\PERS_Char.csv')
pers07_inc= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2007NEWDataDictionary\PERS_Inc.csv')

######################
#2017 DATA from github
######################
unit17_demo= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2017NEWDataDictionary\UNIT_Demo.csv')
unit17_assets= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2017NEWDataDictionary\UNIT_Assets.csv')
unit17_exded= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2017NEWDataDictionary\UNIT_ExDed.csv')
unit17_inc= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2017NEWDataDictionary\UNIT_Inc.csv')
pers17_char= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2017NEWDataDictionary\PERS_Char.csv')
pers17_inc= pd.read_csv(r'C:\Users\efann\Desktop\SNAP\2017NEWDataDictionary\PERS_Inc.csv')

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 New Mexico Correlations (Descending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(corr_df(unit07_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(corr_df(unit07_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(corr_df(unit07_exded, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(corr_df(unit07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(corr_numcol(pers07_char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(corr_numcol(pers07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig(r'C:\Users\efann\Desktop\SNAP\corrD_nm07.png');

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 New Mexico Correlations (Ascending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(corr_df(unit07_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(corr_df(unit07_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(corr_df(unit07_exded, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(corr_df(unit07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(corr_numcol(pers07_char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(corr_numcol(pers07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig(r'C:\Users\efann\Desktop\SNAP\corrA_nm07.png');

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 Nebraska Correlations (Descending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(corr_df(unit07_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(corr_df(unit07_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(corr_df(unit07_exded, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(corr_df(unit07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(corr_numcol(pers07_char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(corr_numcol(pers07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig(r'C:\Users\efann\Desktop\SNAP\corrD_ne07.png');

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 Nebraska Correlations (Acending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(corr_df(unit07_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(corr_df(unit07_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(corr_df(unit07_exded, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(corr_df(unit07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(corr_numcol(pers07_char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(corr_numcol(pers07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig(r'C:\Users\efann\Desktop\SNAP\corrA_ne07.png');

# %%
set1 = list(pd.DataFrame(corr_df(unit07_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set2 = list(pd.DataFrame(corr_df(unit07_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set3 = list(pd.DataFrame(corr_df(unit07_exded, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set4 = list(pd.DataFrame(corr_df(unit07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set5 = list(pd.DataFrame(corr_df(pers07_char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set6 = list(pd.DataFrame(corr_df(pers07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)

set7 = list(pd.DataFrame(corr_df(unit07_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set8 = list(pd.DataFrame(corr_df(unit07_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set9 = list(pd.DataFrame(corr_df(unit07_exded, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set10 = list(pd.DataFrame(corr_df(unit07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set11 = list(pd.DataFrame(corr_df(pers07_char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set12 = list(pd.DataFrame(corr_df(pers07_inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)

corr_features = set1 + set2 + set3 + set4 + set5 + set6 + set7 + set8 + set9 + set10 + set11

# %%
set1 = list(pd.DataFrame(corr_df(unit07_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set2 = list(pd.DataFrame(corr_df(unit07_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set3 = list(pd.DataFrame(corr_df(unit07_exded, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set4 = list(pd.DataFrame(corr_df(unit07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set5 = list(pd.DataFrame(corr_df(pers07_char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set6 = list(pd.DataFrame(corr_df(pers07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)

set7 = list(pd.DataFrame(corr_df(unit07_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set8 = list(pd.DataFrame(corr_df(unit07_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set9 = list(pd.DataFrame(corr_df(unit07_exded, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set10 = list(pd.DataFrame(corr_df(unit07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set11 = list(pd.DataFrame(corr_df(pers07_char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set12 = list(pd.DataFrame(corr_df(pers07_inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)

corr_features = set1 + set2 + set3 + set4 + set5 + set6 + set7 + set8 + set9 + set10 + set11
corr_features=set(corr_features)
corr_features.remove('CAT_ELIG')

# %%
print(f'There are {len(corr_features)} features in corr_features:\n')
corr_features
# Out:
# There are 32 features in corr_features:
# {'CERTHHSZ',
#  'FSASSET',
#  'FSDIS',
#  'FSEARN',
#  'FSERNDE2',
#  'FSERNDED',
#  'FSGA',
#  'FSGRINC',
#  'FSNELDER',
#  'FSNETINC',
#  'FSNONCIT',
#  'FSSLTDE2',
#  'FSSLTDED',
#  'FSSSI',
#  'FSSTDDE2',
#  'FSTANF',
#  'FSTOTDE2',
#  'FSTOTDED',
#  'FSUNEARN',
#  'FSUSIZE',
#  'FSVEHAST',
#  'FSWAGES',
#  'HWGT',
#  'LIQRESOR',
#  'RAWERND',
#  'RAWNET',
#  'REALPROP',
#  'SHELDED',
#  'TANF_IND',
#  'TPOV',
#  'VEHICLEA',
#  'WRK_POOR'}

# %%
corr_features=list(corr_features)
pd.DataFrame(corr_features,columns=['Table 1']).to_csv(r'C:\Users\efann\Desktop\SNAP\corr_features.csv',index=None)

# %%
def final(fullname, dataset):
    """Returns a sliced dataset of columns found in corr_features list."""
    fullname_df = pd.DataFrame()
    for feature in fullname:
        try:
            fullname_df[feature] = dataset[feature]
        except:
            continue
    fullname_df['CAT_ELIG']=dataset['CAT_ELIG']
    return fullname_df

# %%
df1 = final(corr_features,nm07)
df2 = final(corr_features,nm17)
df3 = final(corr_features,ne07)
df4 = final(corr_features,ne17)

# %%
df = pd.concat([df1,df2,df3,df4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3904 entries, 0 to 893
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FSSSI     3904 non-null   float64
#  1   CERTHHSZ  3904 non-null   float64
#  2   FSSLTDED  3904 non-null   float64
#  3   FSERNDED  3904 non-null   float64
#  4   FSUSIZE   3904 non-null   float64
#  5   FSDIS     3904 non-null   float64
#  6   REALPROP  2046 non-null   float64
#  7   FSERNDE2  3904 non-null   float64
#  8   SHELDED   3904 non-null   float64
#  9   FSGA      3904 non-null   float64
#  10  FSSTDDE2  3904 non-null   float64
#  11  FSNETINC  3904 non-null   float64
#  12  TPOV      3904 non-null   float64
#  13  LIQRESOR  2940 non-null   float64
#  14  FSASSET   2940 non-null   float64
#  15  RAWNET    3904 non-null   float64
#  16  FSNONCIT  3904 non-null   float64
#  17  FSNELDER  3904 non-null   float64
#  18  FSGRINC   3904 non-null   float64
#  19  FSTANF    3904 non-null   float64
#  20  WRK_POOR  3904 non-null   float64
#  21  FSEARN    3904 non-null   float64
#  22  FSSLTDE2  3904 non-null   float64
#  23  TANF_IND  3904 non-null   float64
#  24  FSWAGES   3904 non-null   float64
#  25  FSUNEARN  3904 non-null   float64
#  26  HWGT      3904 non-null   float64
#  27  FSTOTDE2  3904 non-null   float64
#  28  FSTOTDED  3904 non-null   float64
#  29  RAWERND   3904 non-null   float64
#  30  CAT_ELIG  3904 non-null   float64
#  31  VEHICLEA  791 non-null    float64
#  32  FSVEHAST  1685 non-null   float64
# dtypes: float64(33)
# memory usage: 1.0 MB

# %%
df.isnull().sum()
# Out:
# FSSSI          0
# CERTHHSZ       0
# FSSLTDED       0
# FSERNDED       0
# FSUSIZE        0
# FSDIS          0
# REALPROP    1858
# FSERNDE2       0
# SHELDED        0
# FSGA           0
# FSSTDDE2       0
# FSNETINC       0
# TPOV           0
# LIQRESOR     964
# FSASSET      964
# RAWNET         0
# FSNONCIT       0
# FSNELDER       0
# FSGRINC        0
# FSTANF         0
# WRK_POOR       0
# FSEARN         0
# FSSLTDE2       0
# TANF_IND       0
# FSWAGES        0
# FSUNEARN       0
# HWGT           0
# FSTOTDE2       0
# FSTOTDED       0
# RAWERND        0
# CAT_ELIG       0
# VEHICLEA    3113
# FSVEHAST    2219
# dtype: int64

# %%
df['VEHICLEA']=df['VEHICLEA'].fillna(1)

# %%
df.isnull().sum()
# Out:
# FSSSI          0
# CERTHHSZ       0
# FSSLTDED       0
# FSERNDED       0
# FSUSIZE        0
# FSDIS          0
# REALPROP    1858
# FSERNDE2       0
# SHELDED        0
# FSGA           0
# FSSTDDE2       0
# FSNETINC       0
# TPOV           0
# LIQRESOR     964
# FSASSET      964
# RAWNET         0
# FSNONCIT       0
# FSNELDER       0
# FSGRINC        0
# FSTANF         0
# WRK_POOR       0
# FSEARN         0
# FSSLTDE2       0
# TANF_IND       0
# FSWAGES        0
# FSUNEARN       0
# HWGT           0
# FSTOTDE2       0
# FSTOTDED       0
# RAWERND        0
# CAT_ELIG       0
# VEHICLEA       0
# FSVEHAST    2219
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.to_csv(r'C:\Users\efann\Desktop\SNAP\final.csv',index=None)
